# %%
r = open('example_title.txt', mode='rt', encoding='utf-8')
doc_read = r.read()
r = open('Five Nights at Freddy\'s_review.csv.txt', mode = 'rt', encoding='utf-8')
doc_read2 = r.read()

# %%
'''
# 불용어
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

stop_words = "게임 은 는 이 가 . ㅋ 왜 ? ㅎ ㅠㅠ !!! !! ! ... ㅎㅎㅎㅎ ㅡㅡ 좋아요 너무 재밌어요 정말 굿 좀 제가 재미있어요 넘 더 ~ ㅠㅠㅠ"
stop_words=stop_words.split(' ')

word_tokens = word_tokenize(doc_read)   
result = [] 

for w in word_tokens: 
    if w not in stop_words: 
        result.append(w) 

print(result)
'''
# Out:
# '\n# 불용어\nfrom nltk.corpus import stopwords \nfrom nltk.tokenize import word_tokenize \n\nstop_words = "게임 은 는 이 가 . ㅋ 왜 ? ㅎ ㅠㅠ !!! !! ! ... ㅎㅎㅎㅎ ㅡㅡ 좋아요 너무 재밌어요 정말 굿 좀 제가 재미있어요 넘 더 ~ ㅠㅠㅠ"\nstop_words=stop_words.split(\' \')\n\nword_tokens = word_tokenize(doc_read)   \nresult = [] \n\nfor w in word_tokens: \n    if w not in stop_words: \n        result.append(w) \n\nprint(result)\n'

# %%
from konlpy.tag import Twitter; t = Twitter()
tokens_ko = t.morphs(doc_read)
#print(tokens_ko)
tokens_ko2 = t.morphs(doc_read2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# ...

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 


stop_words = "굿 게임 은 는 이 가 ~ ㅎㅎ 거 안 에서 ㅋ ㅠㅠ 너무 좋아요 도 을 . 에 요 제 가 재밌어요 ! 정말 ... .. 넘 ? 하고 때 재미있어요 를 들 많이 최고 좀 재미 다 더 로 내"
stop_words=stop_words.split(' ')

result = [] 
result2 = []

for w in tokens_ko: 
    if w not in stop_words: 
        result.append(w) 

        
for w in tokens_ko2: 
    if w not in stop_words: 
        result2.append(w) 
        
print(result2)
# Out:
# ['별', '☆☆☆☆☆', '공포', '라서', '감툭', '튀는데', '밌', '네', '여', '별', '☆☆☆☆☆', '개', '!!!', '베터리', '1', '퍼', '6시', 'ㅋㅋㅋ', '----', '수정', '----', '프레디', '버그', '판', '해봤는데', '1', '버그', '판', '사기', '기능', ':', '인형', '위치', '알', '려', '주', '고', '배터리', '무', '한', '!(', '프레디', '버그', '판', '2.3', '있음', '프레디', '2', '랑', '3', '버그', '판', '별', '3', '개', '깨져있으면', '싶으면', '네이버', '깔아', '보삼', ')', '재미있는데', '....', '갑자기', '시작', '할', '마다', '에러', '뜨면서', '꺼져요', '깨서', '별', '세', '개', '얻었었는데', '삭제', '했다', '다시', '깔아', '보고', '하니까', '데이터', '사라지고', '....', '제발', '고쳐주세요', '이야', '~!', '굿굿', '근데', '4일', '차', '폭', '시가', '잘', '움직여요', '그리고', '프레디', '올', '울음소리', '몇', '번', '울리나요', '5일', '밤', '자꾸', '죽어서', '그리고', '스콧', '님', '보니', '치카', '빨라요', '5초', '씩', '자꾸', '움직', '이고', '그래도', '재미있습니다', '그리고', '폭', '시가', '5일', '밤', '보니부터', '움직이면', '잘', '움직여요', '스콧', '님', '\uf44d', '근데', '5일', '밤', '어려워요', '역시', '다르다', '프레디', '의', '피자', '가게', '제작자', '와', '콘텐츠', '만든', '모든', '분', '께', '감사합니다', '역시', '프레디', 'ㅅㅅ', '말로', '표현', '할수가', '없네', '와', '저', '5일', '밤',
# ...

# %%
import nltk

ko = nltk.Text(result, name=u'꿈의집')   # For Python 2, input `name` as u'유니코드'
ko2 = nltk.Text(result2, name = u'fiveNights')
print(len(ko2.tokens))       # returns number of tokens (document length)
print(len(set(ko2.tokens)))  # returns number of unique tokens
ko.vocab()       
ko2.vocab()
# Out:
# 3573
# 1523
# FreqDist({'프레디': 89, '밤': 81, '잼': 38, '5일': 35, '꿀': 33, '진짜': 31, '배터리': 29, '와': 24, '의': 23, '재재': 23, ...})

# %%
from matplotlib import pylab
pylab.show = lambda: pylab.savefig('some_filename.png')

# %%
from matplotlib import font_manager, rc
font_fname = '/Library/Fonts/AppleGothic.ttf'     # A font of your choice
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)

# %%
ko.plot(50)     # Plot sorted frequency of top 50 tokens
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ko.count('인테리어')   # Counts occurrences
# Out:
# 20

# %%
#ko.dispersion_plot(['집', '가구', '인테리어'])

# %%
from konlpy.tag import Twitter; t = Twitter()
pos = lambda d: ['/'.join(p) for p in t.pos(d, stem=True, norm=True)]
texts_ko = [pos(doc) for doc in ko]

pos = lambda d: ['/'.join(p) for p in t.pos(d, stem=True, norm=True)]
texts_ko2 = [pos(doc2) for doc2 in ko2]
print(texts_ko2)
# Out:
# [['별/Noun'], ['☆☆☆☆☆/Foreign'], ['공포/Noun'], ['라서/Noun'], ['감툭/Noun'], ['튀다/Verb'], ['밌/Noun'], ['네/Noun'], ['여/Noun'], ['별/Noun'], ['☆☆☆☆☆/Foreign'], ['개/Noun'], ['!!!/Punctuation'], ['베터리/Noun'], ['1/Number'], ['퍼/PreEomi'], ['6시/Number'], ['ㅋㅋㅋ/KoreanParticle'], ['----/Punctuation'], ['수정/Noun'], ['----/Punctuation'], ['프레디/Noun'], ['버그/Noun'], ['판/Noun'], ['해봤다/Verb'], ['1/Number'], ['버그/Noun'], ['판/Noun'], ['사기/Noun'], ['기능/Noun'], [':/Punctuation'], ['인형/Noun'], ['위치/Noun'], ['알/Noun'], ['려/Noun'], ['주/Noun'], ['고/Noun'], ['배터리/Noun'], ['무/Noun'], ['하다/Verb'], ['!(/Punctuation'], ['프레디/Noun'], ['버그/Noun'], ['판/Noun'], ['2.3/Number'], ['있다/Adjective'], ['프레디/Noun'], ['2/Number'], ['랑/Josa'], ['3/Number'], ['버그/Noun'], ['판/Noun'], ['별/Noun'], ['3/Number'], ['개/Noun'], ['깨다/Verb'], ['싶다/Verb'], ['네이버/Noun'], ['깔다/Verb'], ['보삼/Noun'], [')/Punctuation'], ['재미있다/Adjective'], ['..../Punctuation'], ['갑자기/Noun'], ['시작/Noun'], ['하다/Verb'], ['마다/Noun'], ['에러/Noun'], ['뜨다/Verb'], ['꺼지다/Ver
# ...

# %%
from gensim import corpora
dictionary_ko = corpora.Dictionary(texts_ko)
dictionary_ko.save(u'ko.dict')  # save dictionary to file for future use

dictionary_ko2 = corpora.Dictionary(texts_ko2)

# %%
from gensim import models
tf_ko = [dictionary_ko.doc2bow(text) for text in texts_ko]
tfidf_model_ko = models.TfidfModel(tf_ko)
tfidf_ko = tfidf_model_ko[tf_ko]
corpora.MmCorpus.serialize('ko.mm', tfidf_ko) # save corpus to file for future use


tf_ko2 = [dictionary_ko2.doc2bow(text) for text in texts_ko2]
tfidf_model_ko2 = models.TfidfModel(tf_ko2)
tfidf_ko2 = tfidf_model_ko2[tf_ko2]
corpora.MmCorpus.serialize('ko.mm', tfidf_ko2) # save corpus to file for future use

# print first 10 elements of first document's tf-idf vector
print(tfidf_ko2.corpus[0][:10])
# print top 10 elements of first document's tf-idf vector
print(sorted(tfidf_ko2.corpus[0], key=lambda x: x[1], reverse=True)[:10])
# print token of most frequent element
print(dictionary_ko2.get(414))
# Out:
# [(0, 1)]
# [(0, 1)]
# 꿀잼/Noun

# %%
import numpy as np; np.random.seed(42)  # optional

ntopics = 3
nwords = 5

lda_ko = models.ldamodel.LdaModel(tfidf_ko, id2word=dictionary_ko, num_topics=ntopics)
print(lda_ko.print_topics(num_topics=ntopics, num_words=nwords))
# Out:
# [(0, '0.030*"집/Noun" + 0.026*"재미있다/Adjective" + 0.022*"재다/Verb" + 0.012*"어렵다/Adjective" + 0.011*"시간/Noun"'), (1, '0.099*"하다/Verb" + 0.045*"있다/Adjective" + 0.027*"같다/Adjective" + 0.015*"가구/Noun" + 0.013*"되다/Verb"'), (2, '0.059*"좋다/Adjective" + 0.049*"꾸미다/Verb" + 0.046*"재밌다/Adjective" + 0.028*"광고/Noun" + 0.021*"돈/Noun"')]

# %%
import numpy as np; np.random.seed(42)  # optional

ntopics = 3
nwords = 5

lda_ko2 = models.ldamodel.LdaModel(tfidf_ko2, id2word=dictionary_ko2, num_topics=ntopics)
print(lda_ko2.print_topics(num_topics=ntopics, num_words=nwords))
# Out:
# [(0, '0.038*"무섭다/Adjective" + 0.027*"오다/Verb" + 0.025*"잼/Noun" + 0.024*"꿀/Noun" + 0.020*"깨다/Verb"'), (1, '0.052*"프레디/Noun" + 0.047*"하다/Verb" + 0.042*"밤/Noun" + 0.032*"있다/Adjective" + 0.028*"재밌다/Adjective"'), (2, '0.015*"5일/Number" + 0.010*"피자/Noun" + 0.010*"좋다/Adjective" + 0.009*"같다/Adjective" + 0.009*"되다/Verb"')]

# %%
from gensim.models import word2vec
wv_model_ko = word2vec.Word2Vec(texts_ko)
wv_model_ko.init_sims(replace=True)
wv_model_ko.save('ko_word2vec.model')

# %%
wv_model_ko.most_similar(pos('집'))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('또/Noun', 0.2904568314552307),
#  ('벌다/Verb', 0.2471969872713089),
#  ('그리고/Conjunction', 0.23000270128250122),
#  ('조금/Noun', 0.21392275393009186),
#  ('원하다/Adjective', 0.2063305675983429),
#  ('여/Noun', 0.19408224523067474),
#  ('에서/Josa', 0.19406162202358246),
#  ('겜/Noun', 0.19334334135055542),
#  ('들다/Verb', 0.19047926366329193),
#  ('되어다/Verb', 0.18824103474617004)]

# %%
# Build LDA model
lda_model = models.ldamodel.LdaModel(corpus=tf_ko,
id2word=id2word,
num_topics=20,
random_state=100,
update_every=1,
chunksize=100,
passes=10,
alpha='auto',
per_word_topics=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-4e0c1515c0f7> in <module>
#       1 # Build LDA model
#       2 lda_model = models.ldamodel.LdaModel(corpus=tf_ko,
# ----> 3 id2word=id2word,
#       4 num_topics=20,
#       5 random_state=100,
#
# NameError: name 'id2word' is not defined

# %%
doc_lda = lda_model[tf_ko]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-479e51bba92c> in <module>
# ----> 1 doc_lda = lda_model[tf_ko]
#
# NameError: name 'lda_model' is not defined
